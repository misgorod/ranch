# %% [markdown]
# success,size,topic,acks,compression,inflight,batch,linger,time,rate,latency

# %%
import csv

metrics = []
with open('metrics/metrics-corr-1-raw.csv', 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        metrics.append(row)

# %%
def to_float(s):
    try:
        s=float(s)
    except ValueError:
        pass    
    return s

for metric in metrics:
    for key in metric:
        metric[key] = to_float(metric[key])

# %%
def filter_unsuccessful(metric):
    if metric['success'] == 0:
        metric['rate'] = 0
        metric['latency'] = -1
        metric['success'] = 1
    return dict(metric)
        
filtered = [filter_unsuccessful(m) for m in metrics]
filtered
# Out:
# [{'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 0.0,
#   'time': 4583.0,
#   'rate': 66.63,
#   'latency': 398.45},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 20.0,
#   'time': 4445.0,
#   'rate': 69.17,
#   'latency': 394.5},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 50.0,
#   'time': 4466.0,
#   'rate': 69.1,
#   'latency': 390.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 100.0,
#   'time': 4477.0,
#   'rate': 69.08,
#   'latency': 377.05},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 150.0,
#   'time': 4669.0,
#   'rate': 65.59,
#   'latency': 404.49},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 200.0,
#   'time': 4447.0,
#   'rate': 69.57,
#   'latency': 388.44},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 300.0,
#   'time': 4557.0,
#   'rate': 67.17,
#   'latency': 401.0},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 500.0,
#   'time': 4573.0,
#   'rate': 66.88,
#   'latency': 400.04},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 700.0,
#   'time': 4408.0,
#   'rate': 69.7,
#   'latency': 382.62},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 0.0,
#   'linger': 1000.0,
#   'time': 4507.0,
#   'rate': 67.98,
#   'latency': 396.16},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 0.0,
#   'time': 4474.0,
#   'rate': 68.67,
#   'latency': 391.95},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 20.0,
#   'time': 4554.0,
#   'rate': 67.26,
#   'latency': 402.97},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 50.0,
#   'time': 4373.0,
#   'rate': 70.8,
#   'latency': 375.53},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 100.0,
#   'time': 4373.0,
#   'rate': 70.56,
#   'latency': 381.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 150.0,
#   'time': 4499.0,
#   'rate': 68.16,
#   'latency': 396.66},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 200.0,
#   'time': 4605.0,
#   'rate': 66.56,
#   'latency': 395.17},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 300.0,
#   'time': 4416.0,
#   'rate': 69.7,
#   'latency': 389.69},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 500.0,
#   'time': 4577.0,
#   'rate': 66.79,
#   'latency': 389.88},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 700.0,
#   'time': 4463.0,
#   'rate': 68.85,
#   'latency': 391.1},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 512.0,
#   'linger': 1000.0,
#   'time': 4584.0,
#   'rate': 66.6,
#   'latency': 394.71},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 0.0,
#   'time': 4360.0,
#   'rate': 71.27,
#   'latency': 373.15},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 20.0,
#   'time': 4422.0,
#   'rate': 69.57,
#   'latency': 389.81},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 50.0,
#   'time': 4584.0,
#   'rate': 66.46,
#   'latency': 402.03},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 100.0,
#   'time': 4565.0,
#   'rate': 67.17,
#   'latency': 403.62},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 150.0,
#   'time': 4584.0,
#   'rate': 66.65,
#   'latency': 404.91},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 200.0,
#   'time': 4443.0,
#   'rate': 69.17,
#   'latency': 385.69},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 300.0,
#   'time': 4469.0,
#   'rate': 68.85,
#   'latency': 385.11},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 500.0,
#   'time': 4410.0,
#   'rate': 70.47,
#   'latency': 378.7},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 700.0,
#   'time': 4379.0,
#   'rate': 70.66,
#   'latency': 381.23},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1024.0,
#   'linger': 1000.0,
#   'time': 4332.0,
#   'rate': 71.33,
#   'latency': 376.53},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 0.0,
#   'time': 4371.0,
#   'rate': 70.54,
#   'latency': 375.62},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 20.0,
#   'time': 4426.0,
#   'rate': 69.68,
#   'latency': 386.63},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 50.0,
#   'time': 4502.0,
#   'rate': 68.63,
#   'latency': 393.32},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 100.0,
#   'time': 4592.0,
#   'rate': 66.53,
#   'latency': 400.7},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 150.0,
#   'time': 4606.0,
#   'rate': 66.24,
#   'latency': 401.83},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 200.0,
#   'time': 4432.0,
#   'rate': 69.91,
#   'latency': 380.51},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 300.0,
#   'time': 4329.0,
#   'rate': 71.43,
#   'latency': 377.54},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 500.0,
#   'time': 4643.0,
#   'rate': 65.59,
#   'latency': 409.52},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 700.0,
#   'time': 4417.0,
#   'rate': 69.75,
#   'latency': 381.07},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8192.0,
#   'linger': 1000.0,
#   'time': 4386.0,
#   'rate': 70.84,
#   'latency': 380.43},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 0.0,
#   'time': 4492.0,
#   'rate': 68.69,
#   'latency': 388.54},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 20.0,
#   'time': 4373.0,
#   'rate': 70.89,
#   'latency': 375.26},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 50.0,
#   'time': 4355.0,
#   'rate': 70.91,
#   'latency': 378.22},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 100.0,
#   'time': 4359.0,
#   'rate': 70.87,
#   'latency': 379.2},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 150.0,
#   'time': 4555.0,
#   'rate': 67.62,
#   'latency': 395.19},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 200.0,
#   'time': 4637.0,
#   'rate': 65.76,
#   'latency': 404.22},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 300.0,
#   'time': 4546.0,
#   'rate': 67.35,
#   'latency': 398.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 500.0,
#   'time': 4520.0,
#   'rate': 68.18,
#   'latency': 395.84},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 700.0,
#   'time': 4323.0,
#   'rate': 72.17,
#   'latency': 371.08},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 16384.0,
#   'linger': 1000.0,
#   'time': 4339.0,
#   'rate': 71.17,
#   'latency': 379.57},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 0.0,
#   'time': 4416.0,
#   'rate': 69.7,
#   'latency': 383.3},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 20.0,
#   'time': 4542.0,
#   'rate': 67.8,
#   'latency': 395.34},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 50.0,
#   'time': 4359.0,
#   'rate': 70.74,
#   'latency': 377.75},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 100.0,
#   'time': 4520.0,
#   'rate': 68.18,
#   'latency': 394.67},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 150.0,
#   'time': 4523.0,
#   'rate': 67.64,
#   'latency': 394.86},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 200.0,
#   'time': 4346.0,
#   'rate': 70.93,
#   'latency': 381.67},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 300.0,
#   'time': 4353.0,
#   'rate': 70.8,
#   'latency': 378.48},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 500.0,
#   'time': 4347.0,
#   'rate': 71.01,
#   'latency': 382.25},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 700.0,
#   'time': 4397.0,
#   'rate': 70.54,
#   'latency': 381.41},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 32768.0,
#   'linger': 1000.0,
#   'time': 4396.0,
#   'rate': 70.0,
#   'latency': 378.12},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 0.0,
#   'time': 4399.0,
#   'rate': 70.5,
#   'latency': 378.42},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 20.0,
#   'time': 4434.0,
#   'rate': 69.17,
#   'latency': 390.65},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 50.0,
#   'time': 4428.0,
#   'rate': 69.51,
#   'latency': 379.28},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 100.0,
#   'time': 4395.0,
#   'rate': 70.04,
#   'latency': 382.74},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 150.0,
#   'time': 4573.0,
#   'rate': 66.93,
#   'latency': 405.23},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 200.0,
#   'time': 4370.0,
#   'rate': 70.54,
#   'latency': 381.17},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 300.0,
#   'time': 4569.0,
#   'rate': 67.1,
#   'latency': 394.95},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 500.0,
#   'time': 4338.0,
#   'rate': 71.81,
#   'latency': 375.45},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 700.0,
#   'time': 4349.0,
#   'rate': 71.15,
#   'latency': 378.6},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 65536.0,
#   'linger': 1000.0,
#   'time': 4312.0,
#   'rate': 71.81,
#   'latency': 375.36},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 0.0,
#   'time': 4267.0,
#   'rate': 72.67,
#   'latency': 371.44},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 20.0,
#   'time': 4441.0,
#   'rate': 69.11,
#   'latency': 388.7},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 50.0,
#   'time': 4373.0,
#   'rate': 70.93,
#   'latency': 375.87},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 100.0,
#   'time': 4509.0,
#   'rate': 67.96,
#   'latency': 394.11},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 150.0,
#   'time': 4321.0,
#   'rate': 71.51,
#   'latency': 372.56},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 200.0,
#   'time': 4591.0,
#   'rate': 66.49,
#   'latency': 401.56},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 300.0,
#   'time': 4488.0,
#   'rate': 68.38,
#   'latency': 395.04},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 500.0,
#   'time': 4541.0,
#   'rate': 67.99,
#   'latency': 397.74},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 700.0,
#   'time': 4537.0,
#   'rate': 67.6,
#   'latency': 387.87},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 131072.0,
#   'linger': 1000.0,
#   'time': 4359.0,
#   'rate': 70.76,
#   'latency': 378.06},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 0.0,
#   'time': 4393.0,
#   'rate': 70.18,
#   'latency': 288.79},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 20.0,
#   'time': 4084.0,
#   'rate': 76.76,
#   'latency': 268.03},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 50.0,
#   'time': 4425.0,
#   'rate': 69.43,
#   'latency': 299.12},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 100.0,
#   'time': 4226.0,
#   'rate': 73.82,
#   'latency': 279.1},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 150.0,
#   'time': 4381.0,
#   'rate': 70.8,
#   'latency': 293.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 200.0,
#   'time': 4424.0,
#   'rate': 69.43,
#   'latency': 295.11},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 300.0,
#   'time': 4050.0,
#   'rate': 77.55,
#   'latency': 259.66},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 500.0,
#   'time': 4494.0,
#   'rate': 68.65,
#   'latency': 298.18},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 700.0,
#   'time': 4273.0,
#   'rate': 73.08,
#   'latency': 280.23},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 524288.0,
#   'linger': 1000.0,
#   'time': 4268.0,
#   'rate': 72.67,
#   'latency': 283.37},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 0.0,
#   'time': 4445.0,
#   'rate': 69.79,
#   'latency': 322.12},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 20.0,
#   'time': 4334.0,
#   'rate': 71.83,
#   'latency': 331.6},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 50.0,
#   'time': 4591.0,
#   'rate': 66.44,
#   'latency': 366.21},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 100.0,
#   'time': 4153.0,
#   'rate': 75.01,
#   'latency': 310.74},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 150.0,
#   'time': 4464.0,
#   'rate': 69.28,
#   'latency': 350.39},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 200.0,
#   'time': 4157.0,
#   'rate': 74.96,
#   'latency': 308.96},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 300.0,
#   'time': 4581.0,
#   'rate': 66.81,
#   'latency': 347.38},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 500.0,
#   'time': 3980.0,
#   'rate': 79.18,
#   'latency': 302.16},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 700.0,
#   'time': 4749.0,
#   'rate': 63.89,
#   'latency': 376.71},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 1048576.0,
#   'linger': 1000.0,
#   'time': 4122.0,
#   'rate': 75.78,
#   'latency': 301.41},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 0.0,
#   'time': 4067.0,
#   'rate': 77.02,
#   'latency': 314.34},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 20.0,
#   'time': 4281.0,
#   'rate': 72.34,
#   'latency': 334.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 50.0,
#   'time': 4553.0,
#   'rate': 67.12,
#   'latency': 369.11},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 100.0,
#   'time': 4216.0,
#   'rate': 73.58,
#   'latency': 329.4},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 150.0,
#   'time': 4337.0,
#   'rate': 71.17,
#   'latency': 334.21},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 200.0,
#   'time': 4098.0,
#   'rate': 76.35,
#   'latency': 309.06},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 300.0,
#   'time': 4246.0,
#   'rate': 72.91,
#   'latency': 344.9},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 500.0,
#   'time': 4698.0,
#   'rate': 65.14,
#   'latency': 372.33},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 700.0,
#   'time': 4150.0,
#   'rate': 75.34,
#   'latency': 320.6},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 2097152.0,
#   'linger': 1000.0,
#   'time': 4395.0,
#   'rate': 70.18,
#   'latency': 354.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 0.0,
#   'time': 4749.0,
#   'rate': 63.98,
#   'latency': 379.78},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 20.0,
#   'time': 4533.0,
#   'rate': 67.49,
#   'latency': 376.22},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 50.0,
#   'time': 4490.0,
#   'rate': 68.39,
#   'latency': 371.7},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 100.0,
#   'time': 4427.0,
#   'rate': 69.51,
#   'latency': 369.27},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 150.0,
#   'time': 4481.0,
#   'rate': 68.49,
#   'latency': 362.55},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 200.0,
#   'time': 4232.0,
#   'rate': 73.48,
#   'latency': 329.92},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 300.0,
#   'time': 4473.0,
#   'rate': 68.82,
#   'latency': 375.08},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 500.0,
#   'time': 4727.0,
#   'rate': 64.65,
#   'latency': 402.36},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 700.0,
#   'time': 4543.0,
#   'rate': 67.78,
#   'latency': 382.27},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 4194304.0,
#   'linger': 1000.0,
#   'time': 4242.0,
#   'rate': 73.1,
#   'latency': 337.14},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 0.0,
#   'time': 5010.0,
#   'rate': 60.0,
#   'latency': 397.47},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 20.0,
#   'time': 5182.0,
#   'rate': 57.67,
#   'latency': 447.37},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 50.0,
#   'time': 5015.0,
#   'rate': 59.74,
#   'latency': 409.67},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 100.0,
#   'time': 4841.0,
#   'rate': 62.45,
#   'latency': 387.81},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 150.0,
#   'time': 4986.0,
#   'rate': 60.39,
#   'latency': 438.36},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 200.0,
#   'time': 5066.0,
#   'rate': 59.23,
#   'latency': 440.19},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 300.0,
#   'time': 5457.0,
#   'rate': 54.65,
#   'latency': 483.89},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 500.0,
#   'time': 5074.0,
#   'rate': 59.18,
#   'latency': 439.37},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 700.0,
#   'time': 4696.0,
#   'rate': 65.09,
#   'latency': 393.44},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 1.0,
#   'batch': 8388608.0,
#   'linger': 1000.0,
#   'time': 5114.0,
#   'rate': 59.03,
#   'latency': 443.4},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 0.0,
#   'time': 3762.0,
#   'rate': 84.99,
#   'latency': 305.04},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 20.0,
#   'time': 3869.0,
#   'rate': 82.34,
#   'latency': 313.69},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 50.0,
#   'time': 4154.0,
#   'rate': 75.18,
#   'latency': 345.54},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 100.0,
#   'time': 3805.0,
#   'rate': 83.44,
#   'latency': 311.94},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 150.0,
#   'time': 4133.0,
#   'rate': 75.54,
#   'latency': 349.71},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 200.0,
#   'time': 4137.0,
#   'rate': 75.69,
#   'latency': 346.46},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 300.0,
#   'time': 3685.0,
#   'rate': 87.07,
#   'latency': 299.41},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 500.0,
#   'time': 3702.0,
#   'rate': 86.99,
#   'latency': 301.6},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 700.0,
#   'time': 4295.0,
#   'rate': 72.21,
#   'latency': 353.07},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 0.0,
#   'linger': 1000.0,
#   'time': 3863.0,
#   'rate': 82.66,
#   'latency': 318.59},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 0.0,
#   'time': 4068.0,
#   'rate': 77.36,
#   'latency': 342.15},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 20.0,
#   'time': 3713.0,
#   'rate': 86.49,
#   'latency': 300.71},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 50.0,
#   'time': 3838.0,
#   'rate': 82.93,
#   'latency': 316.24},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 100.0,
#   'time': 3883.0,
#   'rate': 82.18,
#   'latency': 318.67},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 150.0,
#   'time': 4141.0,
#   'rate': 75.36,
#   'latency': 350.57},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 200.0,
#   'time': 3798.0,
#   'rate': 83.91,
#   'latency': 314.67},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 300.0,
#   'time': 3874.0,
#   'rate': 82.37,
#   'latency': 317.77},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 500.0,
#   'time': 3707.0,
#   'rate': 86.54,
#   'latency': 302.62},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 700.0,
#   'time': 3758.0,
#   'rate': 85.79,
#   'latency': 307.13},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 1000.0,
#   'time': 4165.0,
#   'rate': 74.88,
#   'latency': 350.57},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 0.0,
#   'time': 3708.0,
#   'rate': 86.43,
#   'latency': 301.26},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 20.0,
#   'time': 3824.0,
#   'rate': 83.77,
#   'latency': 311.21},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 50.0,
#   'time': 3721.0,
#   'rate': 85.88,
#   'latency': 302.71},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 100.0,
#   'time': 3867.0,
#   'rate': 81.84,
#   'latency': 318.0},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 150.0,
#   'time': 3842.0,
#   'rate': 82.71,
#   'latency': 320.51},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 200.0,
#   'time': 3689.0,
#   'rate': 86.93,
#   'latency': 301.46},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 300.0,
#   'time': 4109.0,
#   'rate': 76.01,
#   'latency': 346.66},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 500.0,
#   'time': 3790.0,
#   'rate': 84.71,
#   'latency': 303.72},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 700.0,
#   'time': 3738.0,
#   'rate': 85.39,
#   'latency': 305.28},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 1000.0,
#   'time': 3829.0,
#   'rate': 83.09,
#   'latency': 315.24},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 0.0,
#   'time': 3680.0,
#   'rate': 87.34,
#   'latency': 302.01},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 20.0,
#   'time': 4104.0,
#   'rate': 76.76,
#   'latency': 347.52},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 50.0,
#   'time': 3835.0,
#   'rate': 82.96,
#   'latency': 318.16},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 100.0,
#   'time': 3824.0,
#   'rate': 82.98,
#   'latency': 312.35},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 150.0,
#   'time': 3666.0,
#   'rate': 87.52,
#   'latency': 300.64},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 200.0,
#   'time': 3848.0,
#   'rate': 82.58,
#   'latency': 318.89},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 300.0,
#   'time': 3849.0,
#   'rate': 82.66,
#   'latency': 313.18},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 500.0,
#   'time': 3710.0,
#   'rate': 86.05,
#   'latency': 304.29},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 700.0,
#   'time': 4173.0,
#   'rate': 74.51,
#   'latency': 354.72},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 1000.0,
#   'time': 3743.0,
#   'rate': 85.25,
#   'latency': 309.41},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 0.0,
#   'time': 3751.0,
#   'rate': 85.13,
#   'latency': 311.72},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 20.0,
#   'time': 3749.0,
#   'rate': 85.56,
#   'latency': 307.77},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 50.0,
#   'time': 4158.0,
#   'rate': 75.25,
#   'latency': 347.21},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 100.0,
#   'time': 3747.0,
#   'rate': 85.13,
#   'latency': 305.67},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 150.0,
#   'time': 4167.0,
#   'rate': 74.7,
#   'latency': 353.19},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 200.0,
#   'time': 3759.0,
#   'rate': 84.77,
#   'latency': 307.88},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 300.0,
#   'time': 3771.0,
#   'rate': 84.91,
#   'latency': 303.06},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 500.0,
#   'time': 3899.0,
#   'rate': 81.53,
#   'latency': 315.85},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 700.0,
#   'time': 3820.0,
#   'rate': 83.88,
#   'latency': 310.25},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 1000.0,
#   'time': 4028.0,
#   'rate': 78.75,
#   'latency': 323.89},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 0.0,
#   'time': 3744.0,
#   'rate': 85.39,
#   'latency': 308.47},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 20.0,
#   'time': 4147.0,
#   'rate': 75.07,
#   'latency': 351.1},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 50.0,
#   'time': 3807.0,
#   'rate': 83.85,
#   'latency': 305.77},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 100.0,
#   'time': 4102.0,
#   'rate': 76.28,
#   'latency': 345.12},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 150.0,
#   'time': 3786.0,
#   'rate': 83.93,
#   'latency': 304.17},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 200.0,
#   'time': 3824.0,
#   'rate': 83.12,
#   'latency': 317.65},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 300.0,
#   'time': 3848.0,
#   'rate': 83.06,
#   'latency': 315.77},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 500.0,
#   'time': 4080.0,
#   'rate': 76.58,
#   'latency': 345.83},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 700.0,
#   'time': 3803.0,
#   'rate': 83.8,
#   'latency': 315.28},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 1000.0,
#   'time': 3768.0,
#   'rate': 84.66,
#   'latency': 311.0},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 0.0,
#   'time': 3730.0,
#   'rate': 86.54,
#   'latency': 300.19},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 20.0,
#   'time': 3738.0,
#   'rate': 85.76,
#   'latency': 302.4},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 50.0,
#   'time': 3846.0,
#   'rate': 82.69,
#   'latency': 315.99},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 100.0,
#   'time': 3771.0,
#   'rate': 84.57,
#   'latency': 314.32},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 150.0,
#   'time': 3702.0,
#   'rate': 86.63,
#   'latency': 303.04},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 200.0,
#   'time': 3668.0,
#   'rate': 87.46,
#   'latency': 299.11},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 300.0,
#   'time': 3836.0,
#   'rate': 82.71,
#   'latency': 314.06},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 500.0,
#   'time': 3670.0,
#   'rate': 87.55,
#   'latency': 301.1},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 700.0,
#   'time': 3802.0,
#   'rate': 83.66,
#   'latency': 314.33},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 1000.0,
#   'time': 3673.0,
#   'rate': 87.52,
#   'latency': 300.65},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 0.0,
#   'time': 3772.0,
#   'rate': 84.71,
#   'latency': 303.59},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 20.0,
#   'time': 3811.0,
#   'rate': 83.2,
#   'latency': 316.85},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 50.0,
#   'time': 3801.0,
#   'rate': 83.8,
#   'latency': 312.97},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 100.0,
#   'time': 3866.0,
#   'rate': 82.08,
#   'latency': 319.46},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 150.0,
#   'time': 4168.0,
#   'rate': 75.41,
#   'latency': 348.72},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 200.0,
#   'time': 4157.0,
#   'rate': 75.1,
#   'latency': 345.44},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 300.0,
#   'time': 3803.0,
#   'rate': 83.66,
#   'latency': 313.95},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 500.0,
#   'time': 3740.0,
#   'rate': 86.08,
#   'latency': 302.12},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 700.0,
#   'time': 3794.0,
#   'rate': 83.69,
#   'latency': 315.9},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 1000.0,
#   'time': 3758.0,
#   'rate': 84.88,
#   'latency': 309.32},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 0.0,
#   'time': 4157.0,
#   'rate': 74.94,
#   'latency': 274.04},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 20.0,
#   'time': 3647.0,
#   'rate': 88.22,
#   'latency': 226.09},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 50.0,
#   'time': 3725.0,
#   'rate': 86.11,
#   'latency': 231.28},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 100.0,
#   'time': 4205.0,
#   'rate': 74.42,
#   'latency': 275.57},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 150.0,
#   'time': 3805.0,
#   'rate': 83.5,
#   'latency': 238.69},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 200.0,
#   'time': 3786.0,
#   'rate': 84.04,
#   'latency': 236.22},
#  {'success': 1.0,
#   'size': 131072.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 300.0,
#   'time': 4116.0,
#   'rate': 75.83,
# ...
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 700.0,
#   'time': 4572.0,
#   'rate': 67.62,
#   'latency': 401.68},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 512.0,
#   'linger': 1000.0,
#   'time': 4037.0,
#   'rate': 78.22,
#   'latency': 341.26},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 0.0,
#   'time': 4042.0,
#   'rate': 77.95,
#   'latency': 339.91},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 20.0,
#   'time': 4163.0,
#   'rate': 75.16,
#   'latency': 351.34},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 50.0,
#   'time': 4078.0,
#   'rate': 77.32,
#   'latency': 352.91},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 100.0,
#   'time': 3876.0,
#   'rate': 82.08,
#   'latency': 323.98},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 150.0,
#   'time': 4141.0,
#   'rate': 75.56,
#   'latency': 353.33},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 200.0,
#   'time': 4326.0,
#   'rate': 72.32,
#   'latency': 353.52},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 300.0,
#   'time': 4041.0,
#   'rate': 77.91,
#   'latency': 339.57},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 500.0,
#   'time': 4298.0,
#   'rate': 72.34,
#   'latency': 369.11},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 700.0,
#   'time': 3971.0,
#   'rate': 79.63,
#   'latency': 327.57},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 1024.0,
#   'linger': 1000.0,
#   'time': 4085.0,
#   'rate': 76.97,
#   'latency': 329.42},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 0.0,
#   'time': 4361.0,
#   'rate': 71.69,
#   'latency': 370.93},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 20.0,
#   'time': 3980.0,
#   'rate': 79.38,
#   'latency': 326.35},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 50.0,
#   'time': 4134.0,
#   'rate': 76.51,
#   'latency': 346.96},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 100.0,
#   'time': 4426.0,
#   'rate': 69.81,
#   'latency': 383.83},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 150.0,
#   'time': 4387.0,
#   'rate': 70.8,
#   'latency': 375.57},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 200.0,
#   'time': 4241.0,
#   'rate': 73.97,
#   'latency': 361.53},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 300.0,
#   'time': 4310.0,
#   'rate': 72.48,
#   'latency': 366.5},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 500.0,
#   'time': 4215.0,
#   'rate': 74.38,
#   'latency': 348.15},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 700.0,
#   'time': 4447.0,
#   'rate': 69.36,
#   'latency': 384.08},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 8192.0,
#   'linger': 1000.0,
#   'time': 4134.0,
#   'rate': 75.85,
#   'latency': 355.7},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 0.0,
#   'time': 4081.0,
#   'rate': 77.29,
#   'latency': 335.91},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 20.0,
#   'time': 4164.0,
#   'rate': 75.25,
#   'latency': 357.2},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 50.0,
#   'time': 4152.0,
#   'rate': 75.83,
#   'latency': 351.42},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 100.0,
#   'time': 4345.0,
#   'rate': 71.87,
#   'latency': 372.08},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 150.0,
#   'time': 4348.0,
#   'rate': 71.37,
#   'latency': 381.63},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 200.0,
#   'time': 4387.0,
#   'rate': 70.6,
#   'latency': 381.89},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 300.0,
#   'time': 4234.0,
#   'rate': 73.78,
#   'latency': 367.48},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 500.0,
#   'time': 4131.0,
#   'rate': 76.56,
#   'latency': 344.64},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 700.0,
#   'time': 3996.0,
#   'rate': 79.23,
#   'latency': 332.83},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 16384.0,
#   'linger': 1000.0,
#   'time': 4371.0,
#   'rate': 70.89,
#   'latency': 367.12},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 0.0,
#   'time': 3826.0,
#   'rate': 83.71,
#   'latency': 310.18},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 20.0,
#   'time': 4033.0,
#   'rate': 78.36,
#   'latency': 336.03},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 50.0,
#   'time': 3827.0,
#   'rate': 83.41,
#   'latency': 312.29},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 100.0,
#   'time': 4406.0,
#   'rate': 70.16,
#   'latency': 366.38},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 150.0,
#   'time': 4255.0,
#   'rate': 73.25,
#   'latency': 355.09},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 200.0,
#   'time': 4319.0,
#   'rate': 71.79,
#   'latency': 365.11},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 300.0,
#   'time': 4313.0,
#   'rate': 72.19,
#   'latency': 366.48},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 500.0,
#   'time': 3866.0,
#   'rate': 82.37,
#   'latency': 311.05},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 700.0,
#   'time': 4116.0,
#   'rate': 76.26,
#   'latency': 332.03},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 32768.0,
#   'linger': 1000.0,
#   'time': 4186.0,
#   'rate': 74.64,
#   'latency': 353.02},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 0.0,
#   'time': 4130.0,
#   'rate': 76.35,
#   'latency': 348.99},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 20.0,
#   'time': 4723.0,
#   'rate': 64.5,
#   'latency': 409.11},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 50.0,
#   'time': 4415.0,
#   'rate': 70.23,
#   'latency': 386.3},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 100.0,
#   'time': 4108.0,
#   'rate': 77.15,
#   'latency': 352.45},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 150.0,
#   'time': 4072.0,
#   'rate': 78.12,
#   'latency': 325.23},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 200.0,
#   'time': 4373.0,
#   'rate': 71.47,
#   'latency': 377.81},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 300.0,
#   'time': 4102.0,
#   'rate': 76.53,
#   'latency': 345.59},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 500.0,
#   'time': 4069.0,
#   'rate': 77.39,
#   'latency': 345.53},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 700.0,
#   'time': 4508.0,
#   'rate': 68.6,
#   'latency': 390.48},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 65536.0,
#   'linger': 1000.0,
#   'time': 3891.0,
#   'rate': 82.37,
#   'latency': 315.38},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 0.0,
#   'time': 3953.0,
#   'rate': 80.91,
#   'latency': 325.39},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 20.0,
#   'time': 4147.0,
#   'rate': 76.12,
#   'latency': 333.17},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 50.0,
#   'time': 4347.0,
#   'rate': 71.63,
#   'latency': 363.46},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 100.0,
#   'time': 4330.0,
#   'rate': 72.36,
#   'latency': 355.74},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 150.0,
#   'time': 4380.0,
#   'rate': 71.23,
#   'latency': 384.13},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 200.0,
#   'time': 3984.0,
#   'rate': 79.31,
#   'latency': 333.28},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 300.0,
#   'time': 3801.0,
#   'rate': 84.57,
#   'latency': 314.07},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 500.0,
#   'time': 3938.0,
#   'rate': 80.53,
#   'latency': 330.16},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 700.0,
#   'time': 3925.0,
#   'rate': 80.83,
#   'latency': 325.23},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 131072.0,
#   'linger': 1000.0,
#   'time': 4484.0,
#   'rate': 69.11,
#   'latency': 396.41},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 0.0,
#   'time': 4421.0,
#   'rate': 69.93,
#   'latency': 374.09},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 20.0,
#   'time': 4060.0,
#   'rate': 78.31,
#   'latency': 341.37},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 50.0,
#   'time': 4029.0,
#   'rate': 78.24,
#   'latency': 342.05},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 100.0,
#   'time': 4381.0,
#   'rate': 70.78,
#   'latency': 378.73},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 150.0,
#   'time': 4172.0,
#   'rate': 75.1,
#   'latency': 344.4},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 200.0,
#   'time': 3716.0,
#   'rate': 86.52,
#   'latency': 308.67},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 300.0,
#   'time': 4394.0,
#   'rate': 70.58,
#   'latency': 374.91},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 500.0,
#   'time': 3979.0,
#   'rate': 79.8,
#   'latency': 336.71},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 700.0,
#   'time': 3996.0,
#   'rate': 78.96,
#   'latency': 335.09},
#  {'success': 1.0,
#   'size': 1048576.0,
#   'topic': 'test-snappy',
#   'acks': -1.0,
#   'compression': 'snappy',
#   'inflight': 5.0,
#   'batch': 524288.0,
#   'linger': 1000.0,
#   'time': 4071.0,
#   'rate': 77.25,
#   'latency': 343.44},
#  ...]

# %%
from itertools import groupby
from operator import itemgetter

grouper = itemgetter('size', 'acks', 'inflight')

sorted_a = sorted(filtered, key=grouper)
grouped = groupby(sorted_a, key=grouper)
sorted_by_rate = {k:sorted(v, key=itemgetter('rate'), reverse=True)[:25] for k, v in grouped}

# %%
sorted_by_rate
# Out:
# {(128.0,
#   -1.0,
#   1.0): [{'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 20.0,
#    'time': 2245.0,
#    'rate': 170.21,
#    'latency': 8.91}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 1000.0,
#    'time': 2262.0,
#    'rate': 168.98,
#    'latency': 8.38}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 2278.0,
#    'rate': 168.87,
#    'latency': 21.03}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 32768.0,
#    'linger': 200.0,
#    'time': 2269.0,
#    'rate': 168.64,
#    'latency': 3.29}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 20.0,
#    'time': 2263.0,
#    'rate': 168.53,
#    'latency': 5.33}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 150.0,
#    'time': 2268.0,
#    'rate': 168.53,
#    'latency': 8.75}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 100.0,
#    'time': 2281.0,
#    'rate': 168.53,
#    'latency': 22.02}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 300.0,
#    'time': 2268.0,
#    'rate': 168.31,
#    'latency': 18.18}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 100.0,
#    'time': 2271.0,
#    'rate': 167.98,
#    'latency': 8.2}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 200.0,
#    'time': 2281.0,
#    'rate': 167.43,
#    'latency': 4.76}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 500.0,
#    'time': 2293.0,
#    'rate': 167.43,
#    'latency': 18.19}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 700.0,
#    'time': 2291.0,
#    'rate': 166.99,
#    'latency': 20.73}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 20.0,
#    'time': 2279.0,
#    'rate': 166.99,
#    'latency': 22.42}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 300.0,
#    'time': 2294.0,
#    'rate': 166.67,
#    'latency': 8.22}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 1000.0,
#    'time': 2311.0,
#    'rate': 166.67,
#    'latency': 21.43}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 150.0,
#    'time': 2308.0,
#    'rate': 166.34,
#    'latency': 4.99}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 200.0,
#    'time': 2279.0,
#    'rate': 166.34,
#    'latency': 8.42}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 2288.0,
#    'rate': 166.23,
#    'latency': 7.83}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 50.0,
#    'time': 2302.0,
#    'rate': 166.23,
#    'latency': 19.09}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 50.0,
#    'time': 2289.0,
#    'rate': 166.02,
#    'latency': 20.44}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 2291.0,
#    'rate': 166.02,
#    'latency': 17.98}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 50.0,
#    'time': 2299.0,
#    'rate': 165.8,
#    'latency': 5.16}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 700.0,
#    'time': 2309.0,
#    'rate': 165.16,
#    'latency': 8.81}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 2320.0,
#    'rate': 165.05,
#    'latency': 4.96}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 2301.0,
#    'rate': 165.05,
#    'latency': 22.31}],
#  (128.0,
#   -1.0,
#   5.0): [{'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 100.0,
#    'time': 2264.0,
#    'rate': 168.98,
#    'latency': 8.36}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 100.0,
#    'time': 2266.0,
#    'rate': 168.53,
#    'latency': 22.12}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 2273.0,
#    'rate': 168.31,
#    'latency': 21.83}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 2309.0,
#    'rate': 167.65,
#    'latency': 21.5}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 2274.0,
#    'rate': 167.43,
#    'latency': 22.87}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 200.0,
#    'time': 2270.0,
#    'rate': 167.32,
#    'latency': 8.43}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 32768.0,
#    'linger': 150.0,
#    'time': 2281.0,
#    'rate': 167.21,
#    'latency': 3.33}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 1000.0,
#    'time': 2285.0,
#    'rate': 167.1,
#    'latency': 21.79}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 150.0,
#    'time': 2291.0,
#    'rate': 167.1,
#    'latency': 18.53}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 300.0,
#    'time': 2290.0,
#    'rate': 166.88,
#    'latency': 4.68}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 2303.0,
#    'rate': 166.78,
#    'latency': 19.06}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 20.0,
#    'time': 2286.0,
#    'rate': 166.67,
#    'latency': 4.9}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 300.0,
#    'time': 2293.0,
#    'rate': 166.67,
#    'latency': 20.15}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 20.0,
#    'time': 2286.0,
#    'rate': 166.56,
#    'latency': 8.29}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 200.0,
#    'time': 2288.0,
#    'rate': 166.56,
#    'latency': 18.16}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 300.0,
#    'time': 2318.0,
#    'rate': 166.56,
#    'latency': 23.04}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 2337.0,
#    'rate': 166.56,
#    'latency': 22.09}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 50.0,
#    'time': 2293.0,
#    'rate': 166.23,
#    'latency': 18.79}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 1000.0,
#    'time': 2308.0,
#    'rate': 166.02,
#    'latency': 4.69}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 700.0,
#    'time': 2291.0,
#    'rate': 166.02,
#    'latency': 21.61}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 700.0,
#    'time': 2296.0,
#    'rate': 165.91,
#    'latency': 8.7}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 2294.0,
#    'rate': 165.7,
#    'latency': 8.35}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 20.0,
#    'time': 2296.0,
#    'rate': 165.59,
#    'latency': 20.07}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 2295.0,
#    'rate': 165.37,
#    'latency': 5.1}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 50.0,
#    'time': 2306.0,
#    'rate': 165.37,
#    'latency': 8.53}],
#  (128.0,
#   0.0,
#   1.0): [{'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 200.0,
#    'time': 2241.0,
#    'rate': 174.03,
#    'latency': 7.03}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 100.0,
#    'time': 2226.0,
#    'rate': 173.68,
#    'latency': 8.18}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 4194304.0,
#    'linger': 50.0,
#    'time': 2235.0,
#    'rate': 172.97,
#    'latency': 14.62}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 2231.0,
#    'rate': 172.74,
#    'latency': 8.6}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 200.0,
#    'time': 2231.0,
#    'rate': 172.62,
#    'latency': 8.79}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 50.0,
#    'time': 2234.0,
#    'rate': 172.51,
#    'latency': 6.86}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 2258.0,
#    'rate': 172.27,
#    'latency': 8.12}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 2243.0,
#    'rate': 172.04,
#    'latency': 8.66}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 150.0,
#    'time': 2244.0,
#    'rate': 171.35,
#    'latency': 8.15}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 500.0,
#    'time': 2255.0,
#    'rate': 171.01,
#    'latency': 8.08}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 700.0,
#    'time': 2268.0,
#    'rate': 171.01,
#    'latency': 8.29}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 2249.0,
#    'rate': 170.78,
#    'latency': 6.59}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 150.0,
#    'time': 2244.0,
#    'rate': 170.67,
#    'latency': 7.08}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 2244.0,
#    'rate': 170.44,
#    'latency': 2.92}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 300.0,
#    'time': 2265.0,
#    'rate': 170.21,
#    'latency': 6.41}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 4194304.0,
#    'linger': 700.0,
#    'time': 2258.0,
#    'rate': 170.21,
#    'latency': 14.81}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 300.0,
#    'time': 2259.0,
#    'rate': 169.76,
#    'latency': 8.02}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 700.0,
#    'time': 2270.0,
#    'rate': 169.76,
#    'latency': 8.89}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 2264.0,
#    'rate': 169.65,
#    'latency': 1.65}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 20.0,
#    'time': 2280.0,
#    'rate': 169.65,
#    'latency': 7.64}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 2267.0,
#    'rate': 169.65,
#    'latency': 8.86}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 100.0,
#    'time': 2263.0,
#    'rate': 169.31,
#    'latency': 8.3}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 150.0,
#    'time': 2257.0,
#    'rate': 169.2,
#    'latency': 2.86}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 500.0,
#    'time': 2284.0,
#    'rate': 168.98,
#    'latency': 7.45}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 1000.0,
#    'time': 2268.0,
#    'rate': 168.75,
#    'latency': 7.96}],
#  (128.0,
#   0.0,
#   5.0): [{'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 2235.0,
#    'rate': 174.51,
#    'latency': 8.3}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 2228.0,
#    'rate': 173.79,
#    'latency': 8.44}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 2240.0,
#    'rate': 173.09,
#    'latency': 8.42}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 300.0,
#    'time': 2261.0,
#    'rate': 172.62,
#    'latency': 8.13}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 20.0,
#    'time': 2247.0,
#    'rate': 172.39,
#    'latency': 8.27}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 2231.0,
#    'rate': 172.04,
#    'latency': 7.12}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 50.0,
#    'time': 2238.0,
#    'rate': 171.7,
#    'latency': 8.05}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 2238.0,
#    'rate': 171.58,
#    'latency': 8.46}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 20.0,
#    'time': 2245.0,
#    'rate': 171.35,
#    'latency': 7.27}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 200.0,
#    'time': 2263.0,
#    'rate': 171.35,
#    'latency': 8.76}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 500.0,
#    'time': 2263.0,
#    'rate': 171.12,
#    'latency': 6.89}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 700.0,
#    'time': 2248.0,
#    'rate': 170.89,
#    'latency': 7.18}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 100.0,
#    'time': 2271.0,
#    'rate': 170.55,
#    'latency': 15.22}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 50.0,
#    'time': 2252.0,
#    'rate': 170.1,
#    'latency': 2.96}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 300.0,
#    'time': 2253.0,
#    'rate': 170.1,
#    'latency': 2.88}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 700.0,
#    'time': 2252.0,
#    'rate': 170.1,
#    'latency': 2.82}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 100.0,
#    'time': 2280.0,
#    'rate': 169.76,
#    'latency': 8.05}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 300.0,
#    'time': 2272.0,
#    'rate': 169.76,
#    'latency': 6.69}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 1000.0,
#    'time': 2258.0,
#    'rate': 169.76,
#    'latency': 7.21}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 700.0,
#    'time': 2268.0,
#    'rate': 169.65,
#    'latency': 8.77}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 200.0,
#    'time': 2264.0,
#    'rate': 169.54,
#    'latency': 2.92}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 2274.0,
#    'rate': 169.54,
#    'latency': 2.89}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 700.0,
#    'time': 2263.0,
#    'rate': 169.31,
#    'latency': 1.63}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 200.0,
#    'time': 2257.0,
#    'rate': 169.31,
#    'latency': 7.26}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 20.0,
#    'time': 2256.0,
#    'rate': 168.87,
#    'latency': 1.63}],
#  (128.0,
#   1.0,
#   1.0): [{'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 32768.0,
#    'linger': 700.0,
#    'time': 2249.0,
#    'rate': 170.21,
#    'latency': 2.46}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 1000.0,
#    'time': 2261.0,
#    'rate': 169.65,
#    'latency': 6.98}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 20.0,
#    'time': 2257.0,
#    'rate': 169.42,
#    'latency': 4.13}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 200.0,
#    'time': 2262.0,
#    'rate': 169.42,
#    'latency': 16.13}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 50.0,
#    'time': 2288.0,
#    'rate': 169.31,
#    'latency': 15.49}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 500.0,
#    'time': 2275.0,
#    'rate': 168.53,
#    'latency': 15.33}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 2275.0,
#    'rate': 168.53,
#    'latency': 18.0}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 50.0,
#    'time': 2289.0,
#    'rate': 168.09,
#    'latency': 4.2}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 200.0,
#    'time': 2270.0,
#    'rate': 168.09,
#    'latency': 4.14}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 200.0,
#    'time': 2282.0,
#    'rate': 167.98,
#    'latency': 18.62}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 300.0,
#    'time': 2299.0,
#    'rate': 167.98,
#    'latency': 18.16}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 50.0,
#    'time': 2270.0,
#    'rate': 167.87,
#    'latency': 5.8}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 300.0,
#    'time': 2295.0,
#    'rate': 167.76,
#    'latency': 16.38}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 20.0,
#    'time': 2289.0,
#    'rate': 167.54,
#    'latency': 6.75}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 150.0,
#    'time': 2278.0,
#    'rate': 167.54,
#    'latency': 17.29}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 300.0,
#    'time': 2281.0,
#    'rate': 166.88,
#    'latency': 3.63}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 2288.0,
#    'rate': 166.78,
#    'latency': 18.98}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 700.0,
#    'time': 2278.0,
#    'rate': 166.56,
#    'latency': 5.96}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 50.0,
#    'time': 2311.0,
#    'rate': 166.56,
#    'latency': 16.96}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 1000.0,
#    'time': 2308.0,
#    'rate': 166.56,
#    'latency': 14.89}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 200.0,
#    'time': 2289.0,
#    'rate': 166.34,
#    'latency': 16.95}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 700.0,
#    'time': 2316.0,
#    'rate': 166.34,
#    'latency': 14.82}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 1000.0,
#    'time': 2323.0,
#    'rate': 166.13,
#    'latency': 17.57}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 2316.0,
#    'rate': 165.91,
#    'latency': 14.45}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 4194304.0,
#    'linger': 500.0,
#    'time': 2317.0,
#    'rate': 165.7,
#    'latency': 29.04}],
#  (128.0,
#   1.0,
#   5.0): [{'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 300.0,
#    'time': 2252.0,
#    'rate': 170.1,
#    'latency': 14.78}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 20.0,
#    'time': 2280.0,
#    'rate': 168.87,
#    'latency': 18.13}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 700.0,
#    'time': 2285.0,
#    'rate': 168.09,
#    'latency': 6.56}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 50.0,
#    'time': 2276.0,
#    'rate': 167.87,
#    'latency': 6.85}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 2270.0,
#    'rate': 167.87,
#    'latency': 18.43}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 300.0,
#    'time': 2287.0,
#    'rate': 167.54,
#    'latency': 6.66}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 32768.0,
#    'linger': 100.0,
#    'time': 2275.0,
#    'rate': 167.43,
#    'latency': 2.37}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 100.0,
#    'time': 2284.0,
#    'rate': 167.1,
#    'latency': 18.35}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 1000.0,
#    'time': 2308.0,
#    'rate': 166.88,
#    'latency': 15.45}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 150.0,
#    'time': 2321.0,
#    'rate': 166.78,
#    'latency': 15.1}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 150.0,
#    'time': 2288.0,
#    'rate': 166.78,
#    'latency': 14.92}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 700.0,
#    'time': 2280.0,
#    'rate': 166.67,
#    'latency': 3.73}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 100.0,
#    'time': 2281.0,
#    'rate': 166.67,
#    'latency': 6.82}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 50.0,
#    'time': 2279.0,
#    'rate': 166.67,
#    'latency': 17.92}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 2291.0,
#    'rate': 166.56,
#    'latency': 15.41}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 20.0,
#    'time': 2281.0,
#    'rate': 166.23,
#    'latency': 6.8}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 1000.0,
#    'time': 2293.0,
#    'rate': 166.23,
#    'latency': 16.62}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 700.0,
#    'time': 2315.0,
#    'rate': 166.23,
#    'latency': 10.55}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 500.0,
#    'time': 2296.0,
#    'rate': 166.13,
#    'latency': 16.49}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 300.0,
#    'time': 2293.0,
#    'rate': 166.02,
#    'latency': 16.92}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 200.0,
#    'time': 2293.0,
#    'rate': 165.91,
#    'latency': 4.15}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 150.0,
#    'time': 2294.0,
#    'rate': 165.7,
#    'latency': 7.06}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 2289.0,
#    'rate': 165.7,
#    'latency': 18.73}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 1000.0,
#    'time': 2298.0,
#    'rate': 165.7,
#    'latency': 30.26}, {'success': 1.0,
#    'size': 128.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 32768.0,
#    'linger': 700.0,
#    'time': 2279.0,
#    'rate': 165.59,
#    'latency': 2.34}],
#  (256.0,
#   -1.0,
#   1.0): [{'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 100.0,
#    'time': 1805.0,
#    'rate': 248.3,
#    'latency': 16.51}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 300.0,
#    'time': 1779.0,
#    'rate': 247.58,
#    'latency': 15.66}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 1773.0,
#    'rate': 247.34,
#    'latency': 7.23}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 1793.0,
#    'rate': 247.1,
#    'latency': 15.78}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 700.0,
#    'time': 1795.0,
#    'rate': 246.39,
#    'latency': 16.29}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 4194304.0,
#    'linger': 1000.0,
#    'time': 1820.0,
#    'rate': 244.98,
#    'latency': 26.09}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 200.0,
#    'time': 1795.0,
#    'rate': 244.04,
#    'latency': 6.72}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 1820.0,
#    'rate': 243.58,
#    'latency': 16.2}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 1829.0,
#    'rate': 242.88,
#    'latency': 4.65}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 100.0,
#    'time': 1808.0,
#    'rate': 242.88,
#    'latency': 7.83}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 150.0,
#    'time': 1800.0,
#    'rate': 242.88,
#    'latency': 7.53}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 300.0,
#    'time': 1810.0,
#    'rate': 242.88,
#    'latency': 13.63}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 1818.0,
#    'rate': 242.42,
#    'latency': 13.71}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 1836.0,
#    'rate': 242.42,
#    'latency': 16.71}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 1000.0,
#    'time': 1799.0,
#    'rate': 242.19,
#    'latency': 4.6}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 300.0,
#    'time': 1807.0,
#    'rate': 241.74,
#    'latency': 5.43}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 100.0,
#    'time': 1813.0,
#    'rate': 241.51,
#    'latency': 13.09}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 1000.0,
#    'time': 1814.0,
#    'rate': 241.51,
#    'latency': 12.96}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 4194304.0,
#    'linger': 150.0,
#    'time': 1820.0,
#    'rate': 241.51,
#    'latency': 24.4}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 50.0,
#    'time': 1816.0,
#    'rate': 241.05,
#    'latency': 15.15}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 150.0,
#    'time': 1807.0,
#    'rate': 240.83,
#    'latency': 4.63}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 200.0,
#    'time': 1842.0,
#    'rate': 240.83,
#    'latency': 17.03}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 200.0,
#    'time': 1836.0,
#    'rate': 240.6,
#    'latency': 5.75}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 700.0,
#    'time': 1814.0,
#    'rate': 240.6,
#    'latency': 4.87}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 1812.0,
#    'rate': 240.6,
#    'latency': 16.76}],
#  (256.0,
#   -1.0,
#   5.0): [{'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 1780.0,
#    'rate': 249.03,
#    'latency': 15.75}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 200.0,
#    'time': 1804.0,
#    'rate': 247.1,
#    'latency': 16.38}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 150.0,
#    'time': 1782.0,
#    'rate': 246.87,
#    'latency': 4.57}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 1788.0,
#    'rate': 246.63,
#    'latency': 7.06}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 1000.0,
#    'time': 1785.0,
#    'rate': 246.39,
#    'latency': 13.25}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 50.0,
#    'time': 1790.0,
#    'rate': 246.15,
#    'latency': 4.28}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 500.0,
#    'time': 1784.0,
#    'rate': 245.92,
#    'latency': 15.93}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 700.0,
#    'time': 1794.0,
#    'rate': 245.21,
#    'latency': 13.05}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 50.0,
#    'time': 1814.0,
#    'rate': 244.27,
#    'latency': 7.32}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 100.0,
#    'time': 1801.0,
#    'rate': 243.35,
#    'latency': 13.04}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 500.0,
#    'time': 1809.0,
#    'rate': 243.11,
#    'latency': 13.49}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 20.0,
#    'time': 1801.0,
#    'rate': 242.88,
#    'latency': 15.46}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 100.0,
#    'time': 1830.0,
#    'rate': 242.42,
#    'latency': 16.87}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 300.0,
#    'time': 1833.0,
#    'rate': 242.42,
#    'latency': 15.87}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 32768.0,
#    'linger': 150.0,
#    'time': 1814.0,
#    'rate': 242.19,
#    'latency': 3.43}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 1000.0,
#    'time': 1798.0,
#    'rate': 242.19,
#    'latency': 4.41}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 1830.0,
#    'rate': 241.28,
#    'latency': 15.29}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 1817.0,
#    'rate': 240.38,
#    'latency': 13.15}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 50.0,
#    'time': 1811.0,
#    'rate': 240.15,
#    'latency': 24.81}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 200.0,
#    'time': 1840.0,
#    'rate': 239.93,
#    'latency': 12.41}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 1820.0,
#    'rate': 239.48,
#    'latency': 3.95}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 20.0,
#    'time': 1842.0,
#    'rate': 239.48,
#    'latency': 7.3}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 150.0,
#    'time': 1841.0,
#    'rate': 239.48,
#    'latency': 25.26}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 300.0,
#    'time': 1842.0,
#    'rate': 239.48,
#    'latency': 24.48}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': -1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 300.0,
#    'time': 1814.0,
#    'rate': 239.25,
#    'latency': 4.2}],
#  (256.0,
#   0.0,
#   1.0): [{'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 50.0,
#    'time': 1753.0,
#    'rate': 255.49,
#    'latency': 5.48}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 1754.0,
#    'rate': 254.22,
#    'latency': 3.94}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 20.0,
#    'time': 1749.0,
#    'rate': 254.22,
#    'latency': 5.15}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 4194304.0,
#    'linger': 150.0,
#    'time': 1766.0,
#    'rate': 252.47,
#    'latency': 9.47}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 700.0,
#    'time': 1759.0,
#    'rate': 251.97,
#    'latency': 4.29}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 100.0,
#    'time': 1759.0,
#    'rate': 251.72,
#    'latency': 4.03}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 150.0,
#    'time': 1759.0,
#    'rate': 251.47,
#    'latency': 4.11}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 1768.0,
#    'rate': 250.98,
#    'latency': 5.23}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 200.0,
#    'time': 1772.0,
#    'rate': 250.73,
#    'latency': 4.51}, {'success': 1.0,
#    'size': 256.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
# ...
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8192.0,
#    'linger': 50.0,
#    'time': 2797.0,
#    'rate': 127.55,
#    'latency': 198.66}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8192.0,
#    'linger': 200.0,
#    'time': 2810.0,
#    'rate': 127.17,
#    'latency': 202.03}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 2816.0,
#    'rate': 126.61,
#    'latency': 202.81}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 300.0,
#    'time': 2819.0,
#    'rate': 126.42,
#    'latency': 203.61}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 2832.0,
#    'rate': 125.92,
#    'latency': 202.66}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8192.0,
#    'linger': 500.0,
#    'time': 2854.0,
#    'rate': 125.8,
#    'latency': 209.5}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8192.0,
#    'linger': 700.0,
#    'time': 2875.0,
#    'rate': 124.27,
#    'latency': 195.77}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 200.0,
#    'time': 2894.0,
#    'rate': 122.61,
#    'latency': 200.91}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 1000.0,
#    'time': 2937.0,
#    'rate': 120.19,
#    'latency': 200.94}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 2952.0,
#    'rate': 119.07,
#    'latency': 204.44}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 0.0,
#    'time': 2959.0,
#    'rate': 118.63,
#    'latency': 210.09}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 16384.0,
#    'linger': 1000.0,
#    'time': 2981.0,
#    'rate': 117.16,
#    'latency': 214.72}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1024.0,
#    'linger': 150.0,
#    'time': 2997.0,
#    'rate': 116.1,
#    'latency': 211.48}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 512.0,
#    'linger': 150.0,
#    'time': 3036.0,
#    'rate': 114.49,
#    'latency': 223.3}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 300.0,
#    'time': 3034.0,
#    'rate': 114.13,
#    'latency': 231.66}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 16384.0,
#    'linger': 50.0,
#    'time': 3065.0,
#    'rate': 113.58,
#    'latency': 225.52}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 3050.0,
#    'rate': 113.32,
#    'latency': 232.84}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8192.0,
#    'linger': 300.0,
#    'time': 3054.0,
#    'rate': 113.02,
#    'latency': 221.11}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 0.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 500.0,
#    'time': 3093.0,
#    'rate': 112.48,
#    'latency': 231.61}],
#  (4194304.0,
#   1.0,
#   1.0): [{'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 500.0,
#    'time': 2834.0,
#    'rate': 125.74,
#    'latency': 209.38}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1048576.0,
#    'linger': 20.0,
#    'time': 3011.0,
#    'rate': 116.42,
#    'latency': 212.64}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 32768.0,
#    'linger': 300.0,
#    'time': 3000.0,
#    'rate': 116.26,
#    'latency': 219.72}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 2097152.0,
#    'linger': 1000.0,
#    'time': 3033.0,
#    'rate': 115.78,
#    'latency': 223.39}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 50.0,
#    'time': 3014.0,
#    'rate': 115.37,
#    'latency': 225.25}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 100.0,
#    'time': 3037.0,
#    'rate': 114.08,
#    'latency': 230.08}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 16384.0,
#    'linger': 150.0,
#    'time': 3069.0,
#    'rate': 113.53,
#    'latency': 217.61}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 8192.0,
#    'linger': 200.0,
#    'time': 3076.0,
#    'rate': 113.22,
#    'latency': 221.06}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 16384.0,
#    'linger': 500.0,
#    'time': 3068.0,
#    'rate': 112.58,
#    'latency': 222.95}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1024.0,
#    'linger': 0.0,
#    'time': 3068.0,
#    'rate': 112.53,
#    'latency': 226.72}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 32768.0,
#    'linger': 50.0,
#    'time': 3095.0,
#    'rate': 112.53,
#    'latency': 228.42}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 512.0,
#    'linger': 0.0,
#    'time': 3104.0,
#    'rate': 111.99,
#    'latency': 220.78}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 200.0,
#    'time': 3099.0,
#    'rate': 111.79,
#    'latency': 231.22}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 0.0,
#    'linger': 150.0,
#    'time': 3092.0,
#    'rate': 111.01,
#    'latency': 232.28}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 512.0,
#    'linger': 300.0,
#    'time': 3100.0,
#    'rate': 110.77,
#    'latency': 224.64}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 1024.0,
#    'linger': 300.0,
#    'time': 3122.0,
#    'rate': 110.15,
#    'latency': 238.0}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 65536.0,
#    'linger': 100.0,
#    'time': 3160.0,
#    'rate': 109.35,
#    'latency': 235.58}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 8192.0,
#    'linger': 20.0,
#    'time': 3146.0,
#    'rate': 108.84,
#    'latency': 242.94}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 512.0,
#    'linger': 1000.0,
#    'time': 3173.0,
#    'rate': 108.66,
#    'latency': 247.08}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 131072.0,
#    'linger': 500.0,
#    'time': 3147.0,
#    'rate': 108.66,
#    'latency': 243.02}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 500.0,
#    'time': 3148.0,
#    'rate': 108.66,
#    'latency': 237.69}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 524288.0,
#    'linger': 300.0,
#    'time': 3156.0,
#    'rate': 108.47,
#    'latency': 236.36}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 32768.0,
#    'linger': 20.0,
#    'time': 3164.0,
#    'rate': 108.34,
#    'latency': 233.73}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 32768.0,
#    'linger': 1000.0,
#    'time': 3159.0,
#    'rate': 108.25,
#    'latency': 234.53}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 1.0,
#    'batch': 8388608.0,
#    'linger': 700.0,
#    'time': 3157.0,
#    'rate': 108.25,
#    'latency': 159.78}],
#  (4194304.0,
#   1.0,
#   5.0): [{'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 150.0,
#    'time': 2736.0,
#    'rate': 131.76,
#    'latency': 192.16}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 512.0,
#    'linger': 150.0,
#    'time': 2793.0,
#    'rate': 128.39,
#    'latency': 200.03}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 32768.0,
#    'linger': 500.0,
#    'time': 2788.0,
#    'rate': 128.39,
#    'latency': 195.86}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1024.0,
#    'linger': 100.0,
#    'time': 2826.0,
#    'rate': 127.36,
#    'latency': 204.47}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 150.0,
#    'time': 2821.0,
#    'rate': 126.54,
#    'latency': 207.33}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 131072.0,
#    'linger': 300.0,
#    'time': 2866.0,
#    'rate': 124.09,
#    'latency': 201.16}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 700.0,
#    'time': 2859.0,
#    'rate': 124.09,
#    'latency': 212.13}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 150.0,
#    'time': 2911.0,
#    'rate': 121.38,
#    'latency': 211.3}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8388608.0,
#    'linger': 100.0,
#    'time': 2907.0,
#    'rate': 121.04,
#    'latency': 137.13}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 1048576.0,
#    'linger': 300.0,
#    'time': 2924.0,
#    'rate': 120.19,
#    'latency': 211.73}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 512.0,
#    'linger': 300.0,
#    'time': 2929.0,
#    'rate': 119.79,
#    'latency': 205.98}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 4194304.0,
#    'linger': 200.0,
#    'time': 2959.0,
#    'rate': 118.35,
#    'latency': 211.16}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 500.0,
#    'time': 2972.0,
#    'rate': 117.92,
#    'latency': 221.09}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 32768.0,
#    'linger': 700.0,
#    'time': 2982.0,
#    'rate': 117.32,
#    'latency': 215.91}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 16384.0,
#    'linger': 1000.0,
#    'time': 2982.0,
#    'rate': 116.84,
#    'latency': 214.78}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 1000.0,
#    'time': 3033.0,
#    'rate': 114.64,
#    'latency': 220.95}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 150.0,
#    'time': 3032.0,
#    'rate': 114.54,
#    'latency': 220.94}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8388608.0,
#    'linger': 0.0,
#    'time': 3037.0,
#    'rate': 113.98,
#    'latency': 149.38}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 2097152.0,
#    'linger': 20.0,
#    'time': 3049.0,
#    'rate': 113.78,
#    'latency': 216.7}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8388608.0,
#    'linger': 300.0,
#    'time': 3069.0,
#    'rate': 113.78,
#    'latency': 151.47}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 512.0,
#    'linger': 0.0,
#    'time': 3054.0,
#    'rate': 113.73,
#    'latency': 229.86}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 65536.0,
#    'linger': 500.0,
#    'time': 3037.0,
#    'rate': 113.68,
#    'latency': 228.84}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 0.0,
#    'linger': 100.0,
#    'time': 3052.0,
#    'rate': 113.53,
#    'latency': 220.0}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 8192.0,
#    'linger': 50.0,
#    'time': 3081.0,
#    'rate': 113.27,
#    'latency': 225.16}, {'success': 1.0,
#    'size': 4194304.0,
#    'topic': 'test-snappy',
#    'acks': 1.0,
#    'compression': 'snappy',
#    'inflight': 5.0,
#    'batch': 524288.0,
#    'linger': 100.0,
#    'time': 3062.0,
#    'rate': 113.07,
#    'latency': 232.5}]}

# %%
from collections import Counter

counters = {}
for g, metrics in sorted_by_rate.items():
    batch_counts = Counter(m['batch'] for m in metrics)
    linger_counts = Counter(m['linger'] for m in metrics)
    counters[g] = {'batch': batch_counts.most_common(1)[0][0], 'linger': linger_counts.most_common(1)[0][0]}

counters
# Out:
# {(128.0, -1.0, 1.0): {'batch': 131072.0, 'linger': 20.0},
#  (128.0, -1.0, 5.0): {'batch': 2097152.0, 'linger': 20.0},
#  (128.0, 0.0, 1.0): {'batch': 2097152.0, 'linger': 150.0},
#  (128.0, 0.0, 5.0): {'batch': 2097152.0, 'linger': 20.0},
#  (128.0, 1.0, 1.0): {'batch': 1048576.0, 'linger': 50.0},
#  (128.0, 1.0, 5.0): {'batch': 131072.0, 'linger': 700.0},
#  (256.0, -1.0, 1.0): {'batch': 2097152.0, 'linger': 100.0},
#  (256.0, -1.0, 5.0): {'batch': 2097152.0, 'linger': 50.0},
#  (256.0, 0.0, 1.0): {'batch': 2097152.0, 'linger': 700.0},
#  (256.0, 0.0, 5.0): {'batch': 1048576.0, 'linger': 500.0},
#  (256.0, 1.0, 1.0): {'batch': 1048576.0, 'linger': 50.0},
#  (256.0, 1.0, 5.0): {'batch': 1048576.0, 'linger': 500.0},
#  (1024.0, -1.0, 1.0): {'batch': 524288.0, 'linger': 200.0},
#  (1024.0, -1.0, 5.0): {'batch': 1048576.0, 'linger': 20.0},
#  (1024.0, 0.0, 1.0): {'batch': 2097152.0, 'linger': 150.0},
#  (1024.0, 0.0, 5.0): {'batch': 4194304.0, 'linger': 150.0},
#  (1024.0, 1.0, 1.0): {'batch': 4194304.0, 'linger': 200.0},
#  (1024.0, 1.0, 5.0): {'batch': 2097152.0, 'linger': 50.0},
#  (8192.0, -1.0, 1.0): {'batch': 1048576.0, 'linger': 150.0},
#  (8192.0, -1.0, 5.0): {'batch': 131072.0, 'linger': 20.0},
#  (8192.0, 0.0, 1.0): {'batch': 524288.0, 'linger': 100.0},
#  (8192.0, 0.0, 5.0): {'batch': 524288.0, 'linger': 20.0},
#  (8192.0, 1.0, 1.0): {'batch': 524288.0, 'linger': 150.0},
#  (8192.0, 1.0, 5.0): {'batch': 131072.0, 'linger': 700.0},
#  (32768.0, -1.0, 1.0): {'batch': 524288.0, 'linger': 300.0},
#  (32768.0, -1.0, 5.0): {'batch': 131072.0, 'linger': 300.0},
#  (32768.0, 0.0, 1.0): {'batch': 524288.0, 'linger': 150.0},
#  (32768.0, 0.0, 5.0): {'batch': 4194304.0, 'linger': 50.0},
#  (32768.0, 1.0, 1.0): {'batch': 524288.0, 'linger': 50.0},
#  (32768.0, 1.0, 5.0): {'batch': 131072.0, 'linger': 300.0},
#  (65536.0, -1.0, 1.0): {'batch': 524288.0, 'linger': 100.0},
#  (65536.0, -1.0, 5.0): {'batch': 524288.0, 'linger': 700.0},
#  (65536.0, 0.0, 1.0): {'batch': 2097152.0, 'linger': 1000.0},
#  (65536.0, 0.0, 5.0): {'batch': 524288.0, 'linger': 20.0},
#  (65536.0, 1.0, 1.0): {'batch': 1048576.0, 'linger': 20.0},
#  (65536.0, 1.0, 5.0): {'batch': 131072.0, 'linger': 500.0},
#  (131072.0, -1.0, 1.0): {'batch': 2097152.0, 'linger': 1000.0},
#  (131072.0, -1.0, 5.0): {'batch': 65536.0, 'linger': 500.0},
#  (131072.0, 0.0, 1.0): {'batch': 524288.0, 'linger': 300.0},
#  (131072.0, 0.0, 5.0): {'batch': 8192.0, 'linger': 100.0},
#  (131072.0, 1.0, 1.0): {'batch': 1048576.0, 'linger': 0.0},
#  (131072.0, 1.0, 5.0): {'batch': 524288.0, 'linger': 500.0},
#  (524288.0, -1.0, 1.0): {'batch': 32768.0, 'linger': 50.0},
#  (524288.0, -1.0, 5.0): {'batch': 512.0, 'linger': 200.0},
#  (524288.0, 0.0, 1.0): {'batch': 1048576.0, 'linger': 300.0},
#  (524288.0, 0.0, 5.0): {'batch': 1048576.0, 'linger': 500.0},
#  (524288.0, 1.0, 1.0): {'batch': 8192.0, 'linger': 300.0},
#  (524288.0, 1.0, 5.0): {'batch': 8192.0, 'linger': 200.0},
#  (1048576.0, -1.0, 1.0): {'batch': 65536.0, 'linger': 100.0},
#  (1048576.0, -1.0, 5.0): {'batch': 1048576.0, 'linger': 200.0},
#  (1048576.0, 0.0, 1.0): {'batch': 2097152.0, 'linger': 700.0},
#  (1048576.0, 0.0, 5.0): {'batch': 8388608.0, 'linger': 300.0},
#  (1048576.0, 1.0, 1.0): {'batch': 32768.0, 'linger': 100.0},
#  (1048576.0, 1.0, 5.0): {'batch': 65536.0, 'linger': 200.0},
#  (2097152.0, -1.0, 1.0): {'batch': 2097152.0, 'linger': 1000.0},
#  (2097152.0, -1.0, 5.0): {'batch': 524288.0, 'linger': 150.0},
#  (2097152.0, 0.0, 1.0): {'batch': 1024.0, 'linger': 20.0},
#  (2097152.0, 0.0, 5.0): {'batch': 4194304.0, 'linger': 200.0},
#  (2097152.0, 1.0, 1.0): {'batch': 65536.0, 'linger': 150.0},
#  (2097152.0, 1.0, 5.0): {'batch': 8192.0, 'linger': 300.0},
#  (4194304.0, -1.0, 1.0): {'batch': 131072.0, 'linger': 0.0},
#  (4194304.0, -1.0, 5.0): {'batch': 131072.0, 'linger': 50.0},
#  (4194304.0, 0.0, 1.0): {'batch': 16384.0, 'linger': 20.0},
#  (4194304.0, 0.0, 5.0): {'batch': 8192.0, 'linger': 200.0},
#  (4194304.0, 1.0, 1.0): {'batch': 32768.0, 'linger': 500.0},
#  (4194304.0, 1.0, 5.0): {'batch': 512.0, 'linger': 150.0}}

# %%
data_batches={}
data_lingers={}
for conf, metric in counters.items():
    if not (conf[1],conf[2]) in data_batches:
        data_batches[(conf[1],conf[2])] = {}
    data_batches[(conf[1],conf[2])][conf[0]] = metric['batch']
    
    if not (conf[1],conf[2]) in data_lingers:
        data_lingers[(conf[1],conf[2])] = {}
    data_lingers[(conf[1],conf[2])][conf[0]] = metric['linger']
    
print(data_lingers)
print(data_batches)
# Out:
# {(-1.0, 1.0): {128.0: 20.0, 256.0: 100.0, 1024.0: 200.0, 8192.0: 150.0, 32768.0: 300.0, 65536.0: 100.0, 131072.0: 1000.0, 524288.0: 50.0, 1048576.0: 100.0, 2097152.0: 1000.0, 4194304.0: 0.0}, (-1.0, 5.0): {128.0: 20.0, 256.0: 50.0, 1024.0: 20.0, 8192.0: 20.0, 32768.0: 300.0, 65536.0: 700.0, 131072.0: 500.0, 524288.0: 200.0, 1048576.0: 200.0, 2097152.0: 150.0, 4194304.0: 50.0}, (0.0, 1.0): {128.0: 150.0, 256.0: 700.0, 1024.0: 150.0, 8192.0: 100.0, 32768.0: 150.0, 65536.0: 1000.0, 131072.0: 300.0, 524288.0: 300.0, 1048576.0: 700.0, 2097152.0: 20.0, 4194304.0: 20.0}, (0.0, 5.0): {128.0: 20.0, 256.0: 500.0, 1024.0: 150.0, 8192.0: 20.0, 32768.0: 50.0, 65536.0: 20.0, 131072.0: 100.0, 524288.0: 500.0, 1048576.0: 300.0, 2097152.0: 200.0, 4194304.0: 200.0}, (1.0, 1.0): {128.0: 50.0, 256.0: 50.0, 1024.0: 200.0, 8192.0: 150.0, 32768.0: 50.0, 65536.0: 20.0, 131072.0: 0.0, 524288.0: 300.0, 1048576.0: 100.0, 2097152.0: 150.0, 4194304.0: 500.0}, (1.0, 5.0): {128.0: 700.0, 256.0: 500.0, 1024.0: 50.0, 8192.0: 700.0, 32768.0: 300.0, 65536.0: 500.0, 131072.0: 500.0, 524288.0: 200.0, 1048576.0: 200.0, 2097152.0: 300.0, 4194304.0: 150.0}}
# {(-1.0, 1.0): {128.0: 131072.0, 256.0: 2097152.0, 1024.0: 524288.0, 8192.0: 1048576.0, 32768.0: 524288.0, 65536.0: 524288.0, 131072.0: 2097152.0, 524288.0: 32768.0, 1048576.0: 65536.0, 2097152.0: 2097152.0, 4194304.0: 131072.0}, (-1.0, 5.0): {128.0: 2097152.0, 256.0: 2097152.0, 1024.0: 1048576.0, 8192.0: 131072.0, 32768.0: 131072.0, 65536.0: 524288.0, 131072.0: 65536.0, 524288.0: 512.0, 1048576.0: 1048576.0, 2097152.0: 524288.0, 4194304.0: 131072.0}, (0.0, 1.0): {128.0: 2097152.0, 256.0: 2097152.0, 1024.0: 2097152.0, 8192.0: 524288.0, 32768.0: 524288.0, 65536.0: 2097152.0, 131072.0: 524288.0, 524288.0: 1048576.0, 1048576.0: 2097152.0, 2097152.0: 1024.0, 4194304.0: 16384.0}, (0.0, 5.0): {128.0: 2097152.0, 256.0: 1048576.0, 1024.0: 4194304.0, 8192.0: 524288.0, 32768.0: 4194304.0, 65536.0: 524288.0, 131072.0: 8192.0, 524288.0: 1048576.0, 1048576.0: 8388608.0, 2097152.0: 4194304.0, 4194304.0: 8192.0}, (1.0, 1.0): {128.0: 1048576.0, 256.0: 1048576.0, 1024.0: 4194304.0, 8192.0: 524288.0, 32768.0: 524288.0, 65536.0: 1048576.0, 131072.0: 1048576.0, 524288.0: 8192.0, 1048576.0: 32768.0, 2097152.0: 65536.0, 4194304.0: 32768.0}, (1.0, 5.0): {128.0: 131072.0, 256.0: 1048576.0, 1024.0: 2097152.0, 8192.0: 131072.0, 32768.0: 131072.0, 65536.0: 131072.0, 131072.0: 524288.0, 524288.0: 8192.0, 1048576.0: 65536.0, 2097152.0: 8192.0, 4194304.0: 512.0}}

# %%
from scipy.interpolate import interp1d
import numpy as np
from matplotlib import pyplot

xs = np.linspace(128, 4194304, 200)

for conf, metrics in data_lingers.items():
    f1 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='linear')
    f2 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='nearest')
    f3 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='zero')
    f4 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='slinear')
    f5 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='quadratic')
    f6 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='cubic')
    f7 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='previous')
    f8 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='next')
    pyplot.plot(xs, f1(xs))
    pyplot.plot(xs, f2(xs))
    pyplot.plot(xs, f3(xs))
    pyplot.plot(xs, f4(xs))
    pyplot.plot(xs, f5(xs))
    pyplot.plot(xs, f6(xs))
    pyplot.plot(xs, f7(xs))
    pyplot.plot(xs, f8(xs))
    pyplot.axis([0, 4000000, 0, 2000])
    pyplot.legend(['linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'previous', 'next'], loc='best')
    break
pyplot.show()

# %%
import numpy as np
from matplotlib import pyplot

xs = np.linspace(128, 4194304, 200)

for conf, metrics in data_batches.items():
    f1 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='linear')
    f2 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='nearest')
    f3 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='zero')
    f4 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='slinear')
    f5 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='quadratic')
    f6 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='cubic')
    f7 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='previous')
    f8 = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='next')
    pyplot.plot(xs, f1(xs))
    pyplot.plot(xs, f2(xs))
    pyplot.plot(xs, f3(xs))
    pyplot.plot(xs, f4(xs))
    pyplot.plot(xs, f5(xs))
    pyplot.plot(xs, f6(xs))
    pyplot.plot(xs, f7(xs))
    pyplot.plot(xs, f8(xs))
    pyplot.axis([0, 4000000, 0, 4194304])
    pyplot.legend(['linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'previous', 'next'], loc='best')
    break
pyplot.show()

# %%
import numpy as np
from matplotlib import pyplot

xs = np.linspace(128, 4194304, 200)

for conf, metrics in data_batches.items():
    f = interp1d(np.array(list(metrics.keys())), np.array(list(metrics.values())), kind='quadratic')
    pyplot.plot(xs, f(xs))
pyplot.axis([0, 4000000, 0, 4194304])
pyplot.show()
